# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

# %%
db=pd.read_csv("/content/drive/MyDrive/DSBDAL/StudentsPerformance.csv")

# %%
db.isnull()
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0    False                False       False          False          False
# 1    False                False       False          False          False
# 2    False                False       False          False          False
# 3    False                False       False          False          False
# 4    False                False       False          False           True
# 5    False                False       False          False          False
# 6    False                False       False          False          False
# 7    False                False       False          False          False
# 8    False                False       False          False          False
# 9    False                False       False          False          False
# 10   False                False       False          False          False
# 11   False                False       False          False          False
# ...

# %%
series = pd.isnull(db["Math_Score"])

# %%
db[series]
# Out:
# Empty DataFrame
# Columns: [Gender, Number of Instances, Math_Score, Reading_Score, Writing_Score, Placement_Score, Club_Join_Date, Placement Offer Count, Region]
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
db['Gender'] = le.fit_transform(db['Gender'])

# %%
newdb=db

# %%
missing_values = ["Na", "na"]

# %%
missing_values = ["Female", "female"]

# %%
db
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0        1                    1          66             81           64.0
# 1        0                    2          76             79           75.0
# 2        1                    3          75             89           63.0
# 3        0                    4          60             83           71.0
# 4        1                    5          70             86            NaN
# 5        0                    6          63             82           74.0
# 6        1                    7          77             90           71.0
# 7        0                    8          63             81           70.0
# 8        1                    9          62             80           79.0
# 9        0                   10          65             84           68.0
# 10       1                   11          71             88           63.0
# 11       0                   12          67             91           68.0
# ...

# %%
db = pd.read_csv("/content/drive/MyDrive/DSBDAL/StudentsPerformance.csv", na_values = missing_values)

# %%
db
# Out:
#    Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0    male                    1          66             81           64.0
# 1     NaN                    2          76             79           75.0
# 2    male                    3          75             89           63.0
# 3     NaN                    4          60             83           71.0
# 4    male                    5          70             86            NaN
# 5     NaN                    6          63             82           74.0
# 6    male                    7          77             90           71.0
# 7     NaN                    8          63             81           70.0
# 8    male                    9          62             80           79.0
# 9     NaN                   10          65             84           68.0
# 10   male                   11          71             88           63.0
# 11    NaN                   12          67             91           68.0
# ...

# %%
db
# Out:
#    Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0    male                    1          66             81           64.0
# 1     NaN                    2          76             79           75.0
# 2    male                    3          75             89           63.0
# 3     NaN                    4          60             83           71.0
# 4    male                    5          70             86            NaN
# 5     NaN                    6          63             82           74.0
# 6    male                    7          77             90           71.0
# 7     NaN                    8          63             81           70.0
# 8    male                    9          62             80           79.0
# 9     NaN                   10          65             84           68.0
# 10   male                   11          71             88           63.0
# 11    NaN                   12          67             91           68.0
# ...

# %%
ndb=db

# %%
ndb.fillna(0)
# Out:
#    Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0    male                    1          66             81           64.0
# 1       0                    2          76             79           75.0
# 2    male                    3          75             89           63.0
# 3       0                    4          60             83           71.0
# 4    male                    5          70             86            0.0
# 5       0                    6          63             82           74.0
# 6    male                    7          77             90           71.0
# 7       0                    8          63             81           70.0
# 8    male                    9          62             80           79.0
# 9       0                   10          65             84           68.0
# 10   male                   11          71             88           63.0
# 11      0                   12          67             91           68.0
# ...

# %%
db['Math_Score'] = db['Math_Score'].fillna(db['Math_Score'].mean())

# %%
db
# Out:
#    Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0    male                    1          66             81           64.0
# 1     NaN                    2          76             79           75.0
# 2    male                    3          75             89           63.0
# 3     NaN                    4          60             83           71.0
# 4    male                    5          70             86            NaN
# 5     NaN                    6          63             82           74.0
# 6    male                    7          77             90           71.0
# 7     NaN                    8          63             81           70.0
# 8    male                    9          62             80           79.0
# 9     NaN                   10          65             84           68.0
# 10   male                   11          71             88           63.0
# 11    NaN                   12          67             91           68.0
# ...

# %%
data=pd.read_csv("/content/drive/MyDrive/DSBDAL/StudentsPerformance.csv")

# %%
data["Math_Score"] = data["Math_Score"].fillna(data["Math_Score"].median())

# %%
data
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0     male                    1          66             81           64.0
# 1   female                    2          76             79           75.0
# 2     male                    3          75             89           63.0
# 3   female                    4          60             83           71.0
# 4     male                    5          70             86            NaN
# 5   female                    6          63             82           74.0
# 6     male                    7          77             90           71.0
# 7   female                    8          63             81           70.0
# 8     male                    9          62             80           79.0
# 9   female                   10          65             84           68.0
# 10    male                   11          71             88           63.0
# 11  female                   12          67             91           68.0
# ...

# %%
data["Writing_Score"] = data["Writing_Score"].fillna(data["Writing_Score"].std())

# %%
data
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0     male                    1          66             81       64.00000
# 1   female                    2          76             79       75.00000
# 2     male                    3          75             89       63.00000
# 3   female                    4          60             83       71.00000
# 4     male                    5          70             86        6.47009
# 5   female                    6          63             82       74.00000
# 6     male                    7          77             90       71.00000
# 7   female                    8          63             81       70.00000
# 8     male                    9          62             80       79.00000
# 9   female                   10          65             84       68.00000
# 10    male                   11          71             88       63.00000
# 11  female                   12          67             91       68.00000
# ...

# %%
data["Reading_Score"] = data["Reading_Score"].fillna(data["Reading_Score"].min())

# %%
data
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0     male                    1          66             81       64.00000
# 1   female                    2          76             79       75.00000
# 2     male                    3          75             89       63.00000
# 3   female                    4          60             83       71.00000
# 4     male                    5          70             86        6.47009
# 5   female                    6          63             82       74.00000
# 6     male                    7          77             90       71.00000
# 7   female                    8          63             81       70.00000
# 8     male                    9          62             80       79.00000
# 9   female                   10          65             84       68.00000
# 10    male                   11          71             88       63.00000
# 11  female                   12          67             91       68.00000
# ...

# %%
data["Reading_Score"] = data["Reading_Score"].fillna(data["Reading_Score"].max())

# %%
data
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0     male                    1          66             81       64.00000
# 1   female                    2          76             79       75.00000
# 2     male                    3          75             89       63.00000
# 3   female                    4          60             83       71.00000
# 4     male                    5          70             86        6.47009
# 5   female                    6          63             82       74.00000
# 6     male                    7          77             90       71.00000
# 7   female                    8          63             81       70.00000
# 8     male                    9          62             80       79.00000
# 9   female                   10          65             84       68.00000
# 10    male                   11          71             88       63.00000
# 11  female                   12          67             91       68.00000
# ...

# %%
m_v=data['Math_Score'].mean()

# %%
db['Math_Score'].fillna(value=m_v, inplace=True)

# %%
db
# Out:
#    Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0    male                    1          66             81           64.0
# 1     NaN                    2          76             79           75.0
# 2    male                    3          75             89           63.0
# 3     NaN                    4          60             83           71.0
# 4    male                    5          70             86            NaN
# 5     NaN                    6          63             82           74.0
# 6    male                    7          77             90           71.0
# 7     NaN                    8          63             81           70.0
# 8    male                    9          62             80           79.0
# 9     NaN                   10          65             84           68.0
# 10   male                   11          71             88           63.0
# 11    NaN                   12          67             91           68.0
# ...

# %%
ndf=data

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0     male                    1          66             81       64.00000
# 1   female                    2          76             79       75.00000
# 2     male                    3          75             89       63.00000
# 3   female                    4          60             83       71.00000
# 4     male                    5          70             86        6.47009
# 5   female                    6          63             82       74.00000
# 6     male                    7          77             90       71.00000
# 7   female                    8          63             81       70.00000
# 8     male                    9          62             80       79.00000
# 9   female                   10          65             84       68.00000
# 10    male                   11          71             88       63.00000
# 11  female                   12          67             91       68.00000
# ...

# %%
#Replacing null value with -99 in Region coloum

# %%
#Replacing null value with Nashik in Region coloum

# %%
ndf.replace(to_replace = np.nan, value = "Nashik")
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0     male                    1          66             81       64.00000
# 1   female                    2          76             79       75.00000
# 2     male                    3          75             89       63.00000
# 3   female                    4          60             83       71.00000
# 4     male                    5          70             86        6.47009
# 5   female                    6          63             82       74.00000
# 6     male                    7          77             90       71.00000
# 7   female                    8          63             81       70.00000
# 8     male                    9          62             80       79.00000
# 9   female                   10          65             84       68.00000
# 10    male                   11          71             88       63.00000
# 11  female                   12          67             91       68.00000
# ...

# %%
ndf.dropna()
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0     male                    1          66             81       64.00000
# 1   female                    2          76             79       75.00000
# 2     male                    3          75             89       63.00000
# 3   female                    4          60             83       71.00000
# 4     male                    5          70             86        6.47009
# 5   female                    6          63             82       74.00000
# 6     male                    7          77             90       71.00000
# 7   female                    8          63             81       70.00000
# 8     male                    9          62             80       79.00000
# 9   female                   10          65             84       68.00000
# 10    male                   11          71             88       63.00000
# 11  female                   12          67             91       68.00000
# ...

# %%
ndf.dropna(how = 'all')
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0     male                    1          66             81       64.00000
# 1   female                    2          76             79       75.00000
# 2     male                    3          75             89       63.00000
# 3   female                    4          60             83       71.00000
# 4     male                    5          70             86        6.47009
# 5   female                    6          63             82       74.00000
# 6     male                    7          77             90       71.00000
# 7   female                    8          63             81       70.00000
# 8     male                    9          62             80       79.00000
# 9   female                   10          65             84       68.00000
# 10    male                   11          71             88       63.00000
# 11  female                   12          67             91       68.00000
# ...

# %% [markdown]
# new_data = ndf.dropna(axis = 0, how ='any')

# %%
new_data = ndf.dropna(axis = 0, how ='any')
new_data
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0     male                    1          66             81       64.00000
# 1   female                    2          76             79       75.00000
# 2     male                    3          75             89       63.00000
# 3   female                    4          60             83       71.00000
# 4     male                    5          70             86        6.47009
# 5   female                    6          63             82       74.00000
# 6     male                    7          77             90       71.00000
# 7   female                    8          63             81       70.00000
# 8     male                    9          62             80       79.00000
# 9   female                   10          65             84       68.00000
# 10    male                   11          71             88       63.00000
# 11  female                   12          67             91       68.00000
# ...

# %%
col = ['Math_Score', 'Reading_Score' ,'Placement_Score','Writing_Score']

# %%
new_data.boxplot(col)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/drive/MyDrive/DSBDAL/StudentsPerformance.csv")

# %%
df
# Out:
#     Gender  Number of Instances  Math_Score  Reading_Score  Writing_Score  \
# 0     male                    1          66             81           64.0
# 1   female                    2          76             79           75.0
# 2     male                    3          75             89           63.0
# 3   female                    4          60             83           71.0
# 4     male                    5          70             86            NaN
# 5   female                    6          63             82           74.0
# 6     male                    7          77             90           71.0
# 7   female                    8          63             81           70.0
# 8     male                    9          62             80           79.0
# 9   female                   10          65             84           68.0
# 10    male                   11          71             88           63.0
# 11  female                   12          67             91           68.0
# ...

# %%
fig, ax = plt.subplots(figsize = (18,10))

# %%
ax.scatter(df['Placement_Score'], df['Placement Offer Count'])

# %%
plt.show()

# %%
ax.set_xlabel('(Proportion non-retail business acres)/(town)')
# Out:
# Text(0.5, 4.4444444444444375, '(Proportion non-retail business acres)/(town)')

# %%
ax.set_ylabel('(Full-value property-tax rate)/($10,000)')
# Out:
# Text(4.444444444444452, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
print(np.where((df['Placement_Score']<50) & (df['Placement Offer Count']>1)))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where((df['Placement_Score']>85) & (df['Placement Offer Count']<3)))
# Out:
# (array([], dtype=int64),)

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['Placement_Score']))

# %%
print(z)
# Out:
# 0     0.159046
# 1     1.309071
# 2     1.064384
# 3     0.819698
# 4     0.770761
# 5     0.281389
# 6     1.260133
# 7     1.137790
# 8     0.159046
# 9     0.942041
# 10    1.260133
# 11    1.504819
# 12    1.627162
# 13    0.207983
# 14    0.159046
# 15    2.532501
# 16    1.186727
# 17    0.159046
# 18    1.015447
# 19    0.159046
# 20    0.281389
# 21    0.648418
# 22    1.186727
# 23    0.893104
# 24    0.207983
# 25    0.942041
# 26    0.403732
# 27    0.648418
# 28    1.186727
# 29    0.942041
# Name: Placement_Score, dtype: float64

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z <threshold)

# %%
sample_outliers
# Out:
# (array([ 0,  8, 14, 17, 19]),)

# %%
sorted_rscore= sorted(df['Reading_Score'])

# %%
sorted_rscore
# Out:
# [75,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  81,
#  81,
#  82,
#  82,
#  82,
#  82,
#  83,
#  84,
#  84,
#  85,
#  85,
#  85,
#  86,
#  86,
#  86,
#  87,
#  88,
#  89,
#  90,
#  90,
#  91,
#  91,
#  91]

# %%
q1 = np.percentile(sorted_rscore, 25)

# %%
q3 = np.percentile(sorted_rscore, 75)

# %%
print(q1,q3)
# Out:
# 81.0 86.75

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)

# %%
upr_bound = q3+(1.5*IQR)

# %%
print(lwr_bound, upr_bound)
# Out:
# 72.375 95.375
