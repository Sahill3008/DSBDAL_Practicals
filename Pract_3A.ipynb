# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/Mall_Customers.csv")

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.mean()
# Out:
# <ipython-input-13-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# CustomerID                100.50
# Age                        38.85
# Annual Income (k$)         60.56
# Spending Score (1-100)     50.20
# dtype: float64

# %%
data.loc[:,'Age'].mean()
# Out:
# 38.85

# %%
data.mean(axis=1)[0:4]
# Out:
# <ipython-input-15-61a265fa2992>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean(axis=1)[0:4]
# 0    18.50
# 1    29.75
# 2    11.25
# 3    30.00
# dtype: float64

# %%
data.median()
# Out:
# <ipython-input-16-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# CustomerID                100.5
# Age                        36.0
# Annual Income (k$)         61.5
# Spending Score (1-100)     50.0
# dtype: float64

# %%
data.loc[:,'Age'].median()
# Out:
# 36.0

# %%
data.median(axis=1)[0:4]
# Out:
# <ipython-input-20-a44f7a0c1a72>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median(axis=1)[0:4]
# 0    17.0
# 1    18.0
# 2    11.0
# 3    19.5
# dtype: float64

# %%
data.mode()
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  Female  32.0                54.0                    42.0
# 1             2     NaN   NaN                78.0                     NaN
# 2             3     NaN   NaN                 NaN                     NaN
# 3             4     NaN   NaN                 NaN                     NaN
# 4             5     NaN   NaN                 NaN                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         196     NaN   NaN                 NaN                     NaN
# 196         197     NaN   NaN                 NaN                     NaN
# 197         198     NaN   NaN                 NaN                     NaN
# 198         199     NaN   NaN                 NaN                     NaN
# 199         200     NaN   NaN                 NaN                     NaN
#
# [200 rows x 5 columns]

# %%
data.loc[:,'Age'].mode()
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
data.min()
# Out:
# CustomerID                     1
# Gender                    Female
# Age                           18
# Annual Income (k$)            15
# Spending Score (1-100)         1
# dtype: object

# %%
data.loc[:,'Age'].min(skipna = False)
# Out:
# 18

# %%
data.max()
# Out:
# CustomerID                 200
# Gender                    Male
# Age                         70
# Annual Income (k$)         137
# Spending Score (1-100)      99
# dtype: object

# %%
data.loc[:,'Annual Income (k$)'].min(skipna = False)
# Out:
# 15

# %%
data.std()
# Out:
# <ipython-input-27-a47ac8255c06>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# CustomerID                57.879185
# Age                       13.969007
# Annual Income (k$)        26.264721
# Spending Score (1-100)    25.823522
# dtype: float64

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.loc[:,'Age'].std()
# Out:
# 13.96900733155888

# %%
data.std(axis=1)[0:4]
# Out:
# <ipython-input-30-8706f85723b6>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std(axis=1)[0:4]
# 0    15.695010
# 1    35.074920
# 2     8.057088
# 3    32.300671
# dtype: float64

# %%
data.std(axis=1)[0:4]
# Out:
# <ipython-input-31-8706f85723b6>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std(axis=1)[0:4]
# 0    15.695010
# 1    35.074920
# 2     8.057088
# 3    32.300671
# dtype: float64

# %%
data_u=data.rename(columns= {'Annual Income k$)':'Age'},inplace=False)

# %%
data_u
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
(data_u.groupby(['CustomerID']).Age.mean())
# Out:
# CustomerID
# 1      19.0
# 2      21.0
# 3      20.0
# 4      23.0
# 5      31.0
#        ...
# 196    35.0
# 197    45.0
# 198    32.0
# 199    32.0
# 200    30.0
# Name: Age, Length: 200, dtype: float64

# %%
from sklearn import preprocessing

# %%
enc = preprocessing.OneHotEncoder()

# %%
enc_df = pd.DataFrame(enc.fit_transform(data[['CustomerID']]).toarray())

# %%
enc_df.sum()
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 195    1.0
# 196    1.0
# 197    1.0
# 198    1.0
# 199    1.0
# Length: 200, dtype: float64
